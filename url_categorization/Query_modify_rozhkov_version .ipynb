# %% [markdown]
# Этот код используется для составления SQL-запроса, который позволяет оценить процент сайтов, попадающих в заранее определенные категории, используя данные, полученные с помощью указанных сервисов. Запрос формирует условия для классификации доменов по категориям, сравнивая значения в столбце req_host с регулярными выражениями, связанными с каждой категорией. Статистика по категориям помогает оценить, насколько эффективно проделанная работа по категоризации позволяет в будущем классифицировать сайты с использованием этого запроса. Код включает в себя агрегацию данных по категориям, генерацию SQL-запроса и вывод результата для анализа.

# %% [markdown]
# 1. Загрузка библиотек: Импортируются необходимые библиотеки для работы с данными (pandas), обработки паролей (getpass), работы с операционной системой (os), а также для работы с JSON и строками (json, ast).
#
# 2. Выгрузка данных: Загружается CSV файл combined_hosts_with_fixed_regex_v4.csv в DataFrame df_reg. Далее с помощью метода value_counts() подсчитываются уникальные значения в столбце 'cat_popular'.
#
# 3. Агрегация данных: Данные группируются по столбцу 'cat_popular', и для каждой категории собираются соответствующие значения из столбца 'url_regex_mod' в виде списка. Результат сохраняется в новый DataFrame df_reg_unite.
#
# 4. Формирование SQL запроса: Создается строка SQL-запроса, начиная с подзапроса, в котором создаются условия для классификации req_host по категориям. Для каждой категории из DataFrame df_reg_unite формируются условия WHEN для функции match(), которая проверяет соответствие доменов в req_host. Если совпадение найдено, то присваивается соответствующая категория.
#
# 5. Заполнение и завершение строки запроса: Для каждой категории добавляются строки с условиями WHEN, где домены (из списка в df_reg_unite) добавляются с помощью метода join(). Результирующая строка расширяется с каждым условием и завершается дополнительными операциями, такими как фильтрация по дате и времени, а также групировка и сортировка по категориям. Запрос выводится в консоль с помощью print().

# %% [markdown]
# 1. Загрузка библиотек

# %%
import pandas as pd
import getpass
import os
import json
import ast

# %% [markdown]
# 2. Выгрузка данных

# %%
df_reg = pd.read_csv('combined_hosts_with_fixed_regex_v40.csv')

df_reg['cat_popular'].value_counts()
# Out:
# cat_popular
# information technology        764
# ip address                    422
# computersandsoftware          263
# business                      207
# search engines and portals    202
#                              ...
# food services                   1
# gaming platforms                1
# social media tools              1
# sports platforms                1
# lifestyle                       1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# 3. Агрегация данных

# %%
df_reg_unite = df_reg.groupby('cat_popular').agg(
    {'url_regex_mod': list}
).reset_index()
df_reg_unite
# Out:
#                              cat_popular  \
# 0                        Advertisements.
# 1    Business/Economy (alphaMountain.ai)
# 2           Malicious (alphaMountain.ai)
# 3              Phishing and Other Frauds
# 4          Suspicious (alphaMountain.ai)
# ..                                   ...
# 174                        web analytics
# 175                          web hosting
# 176                   web infrastructure
# 177                              webmail
# 178                        website tools
#
#                                          url_regex_mod
# 0    [^([\w-]+\.)*(www\.)?mxptint\.(net)$, ^([\w-]+...
# 1    [^([\w-]+\.)*(www\.)?xn--80aebkobnwfcnsfk1e0h\...
# 2                                     [34.160.111.145]
# 3    [^([\w-]+\.)*(www\.)?dolphin-anty-mirror\.(org)$]
# 4                                     [146.190.27.215]
# ..                                                 ...
# 174  [^([\w-]+\.)*(www\.)?digitaltarget\.(ru)$, 87....
# 175  [^([\w-]+\.)*(www\.)?com\.(ua)$, ^([\w-]+\.)*(...
# 176  [^([\w-]+\.)*(www\.)?kimberlite\.(io)$, ^([\w-...
# 177  [^([\w-]+\.)*(www\.)?mail\.(ru)$, ^([\w-]+\.)*...
# 178              [^([\w-]+\.)*(www\.)?wixapps\.(net)$]
#
# [179 rows x 2 columns]

# %% [markdown]
# 4. Формирование SQL запроса:

# %%
string = '''with a as (
	select
		cn, 
		proxy_ip,
		proxy_port,
		ts_millis,
		proxy_service, --group
		error, --count
		tx_bytes, --sum
		rx_bytes, --sum
		req_host, --count(distinct)
        CASE \n'''


for cat, regs in df_reg_unite.values:
    string += "\t\t\tWHEN match(req_host, '"
    string += "') +\n\t\t\t\t match(req_host, '".join(regs)
    string += f"') > 0 THEN '{cat}'\n"
    
string += """		ELSE 'other' END req_category2
        from zprx.zproxy_reqs_v1__merge zrvm 
		where 1=1
			and toYYYYMM(ts_millis) = toYYYYMM(toDate('2021-09-18'))
			and ts_millis > toDateTime('2021-09-18') 
			and ts_millis <= addHours(toDateTime('2021-09-18'), 24)
)
select 
	req_category2,
	count(*) as cnt
from a
group by 
	req_category2
order by 
	cnt desc
"""

# %% [markdown]
# 5. Заполнение строки запроса и завершение запроса

# %% [markdown]
# Этот код я использую для запроса в clickhouse. На основе полученного результата запроса, смотрю, сколько процентов занимает категория others

# %%
string = '''with a as (
    select
        cn, 
        proxy_ip,
        proxy_port,
        ts_millis,
        proxy_service, --group
        error, --count
        tx_bytes, --sum
        rx_bytes, --sum
        req_host, --count(distinct)
        CASE \n'''


for cat, regs in df_reg_unite.values:
    string += f"{' '*12}WHEN multiMatchAny(req_host, [\n{' '*16}'"
    string += f"',\n{' '*16}'".join(regs)
    string += f"'\n{' '*12}]) > 0 THEN '{cat}'\n"
    
string += """        ELSE 'other' END req_category2
        from zprx.zproxy_reqs_v1__merge zrvm 
        where 1=1
            and toYYYYMM(ts_millis) = toYYYYMM(toDate('2021-09-18'))
            and ts_millis > toDateTime('2021-09-18') 
            and ts_millis <= addHours(toDateTime('2021-09-18'), 24)
)
select 
    req_category2,
    count(*) as cnt
from a
group by 
    req_category2
order by 
    cnt desc
"""
print(string)
# Out:
# with a as (
#     select
#         cn,
#         proxy_ip,
#         proxy_port,
#         ts_millis,
#         proxy_service, --group
#         error, --count
#         tx_bytes, --sum
#         rx_bytes, --sum
#         req_host, --count(distinct)
#         CASE
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?mxptint\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mxptint\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mxptint\.(net)$'
#             ]) > 0 THEN 'Advertisements.'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?xn--80aebkobnwfcnsfk1e0h\.(xn--p1ai)$'
#             ]) > 0 THEN 'Business/Economy (alphaMountain.ai)'
#             WHEN multiMatchAny(req_host, [
#                 '34.160.111.145'
#             ]) > 0 THEN 'Malicious (alphaMountain.ai)'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?dolphin-anty-mirror\.(org)$'
#             ]) > 0 THEN 'Phishing and Other Frauds'
#             WHEN multiMatchAny(req_host, [
#                 '146.190.27.215'
#             ]) > 0 THEN 'Suspicious (alphaMountain.ai)'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?presentprofi\.(ru)$'
#             ]) > 0 THEN 'Uncategorized.'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?hs-banner\.(com)$'
#             ]) > 0 THEN 'ad/tracking services'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?yadro\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tapad\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adriver\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rlcdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?simpli\.(fi)$',
#                 '^([\w-]+\.)*(www\.)?adriver\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?yieldmo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lijit\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adriver\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?lijit\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?adriver\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rlcdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adriver\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?blismedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teads\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?outbrain\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?outbrain\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rlcdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teads\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?tapad\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?simpli\.(fi)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mgid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?justpremium\.(com)$',
#                 '^([\w-]+\.)*(www\.)?innovid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?infolinks\.(com)$',
#                 '^([\w-]+\.)*(www\.)?innovid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tapad\.(com)$',
#                 '^([\w-]+\.)*(www\.)?innovid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?extend\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?adswizz\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lijit\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?remerge\.(io)$',
#                 '^([\w-]+\.)*(www\.)?mgid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?innovid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?yieldmo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rlcdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?simpli\.(fi)$',
#                 '^([\w-]+\.)*(www\.)?voicefive\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?truoptik\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amplitude\.(com)$',
#                 '^([\w-]+\.)*(www\.)?getpublica\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adition\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teads\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?mgid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?exponea\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teads\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?outbrain\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?survata\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mediavine\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mgid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?digitalcaramel\.(com)$',
#                 '^([\w-]+\.)*(www\.)?outbrain\.(com)$',
#                 '^([\w-]+\.)*(www\.)?yieldmo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?reson8\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ispot\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?simpli\.(fi)$',
#                 '^([\w-]+\.)*(www\.)?mgid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teads\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?adlightning\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lijit\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amplitude\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?simpli\.(fi)$'
#             ]) > 0 THEN 'ads'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?idealmedia\.(io)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?teemooge\.(net)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?idealmedia\.(io)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?presage\.(io)$',
#                 '^([\w-]+\.)*(www\.)?gumgum\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?braze\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kargo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?idealmedia\.(io)$',
#                 '^([\w-]+\.)*(www\.)?idealmedia\.(io)$',
#                 '^([\w-]+\.)*(www\.)?braze\.(com)$'
#             ]) > 0 THEN 'adsnetwork'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?big-razmer\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?stripchat\.(com)$',
#                 '^([\w-]+\.)*(www\.)?chaturbate\.(com)$'
#             ]) > 0 THEN 'adult content'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?googleadservices\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googlesyndication\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?googlesyndication\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?2mdn\.(net)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?googlesyndication\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidr\.(io)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mradx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?ads-twitter\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2mdn\.(net)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adhigh\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?w55c\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sitescout\.(com)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adentifi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?owneriq\.(net)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?omnitagjs\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smaato\.(net)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '^([\w-]+\.)*(www\.)?postrelease\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sonobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tynt\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adserv\.(us)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adgrx\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adserv\.(us)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mookie1\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googleadservices\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?tremorhub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?newrotatormarch23\.(bid)$',
#                 '^([\w-]+\.)*(www\.)?undertone\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adroll\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '^([\w-]+\.)*(www\.)?fastclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tynt\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?imganalytics\.(com)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsensecustomsearchads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?casalemedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adroll\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mookie1\.(com)$',
#                 '^([\w-]+\.)*(www\.)?omnitagjs\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?admedo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?storygize\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tynt\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adhigh\.(net)$',
#                 '^([\w-]+\.)*(www\.)?w55c\.(net)$',
#                 '^([\w-]+\.)*(www\.)?dtscout\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?outbrainimg\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tremorhub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?terratraf\.(com)$',
#                 '77.88.21.90',
#                 '213.180.204.90',
#                 '93.158.134.90',
#                 '87.250.250.90',
#                 '213.180.193.90',
#                 '^([\w-]+\.)*(www\.)?w55c\.(net)$',
#                 '^([\w-]+\.)*(www\.)?omnitagjs\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tremorhub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidr\.(io)$',
#                 '^([\w-]+\.)*(www\.)?mookie1\.(com)$',
#                 '^([\w-]+\.)*(www\.)?advertising\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tynt\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adroll\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pubmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dtscout\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleclick\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?eqads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rubiconproject\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smartadserver\.(com)$',
#                 '34.98.64.218',
#                 '35.244.159.8',
#                 '^([\w-]+\.)*(www\.)?undertone\.(com)$',
#                 '^([\w-]+\.)*(www\.)?amazon-adsystem\.(com)$'
#             ]) > 0 THEN 'advertisements'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?adsafeprotected\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidswitch\.(net)$',
#                 '^([\w-]+\.)*(www\.)?ufouxbwn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsappier\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidster\.(net)$',
#                 '^([\w-]+\.)*(www\.)?adsafeprotected\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsafeprotected\.(com)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?liadm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?contextweb\.(com)$',
#                 '^([\w-]+\.)*(www\.)?moatads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?growplow\.(events)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?targetimg1\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mfadsrvr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?liadm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsafeprotected\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ad-delivery\.(net)$',
#                 '^([\w-]+\.)*(www\.)?new-programmatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?al-adtech\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gplinks\.(co)$',
#                 '^([\w-]+\.)*(www\.)?gonet-ads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?xn--90adear\.(xn--p1ai)$',
#                 '^([\w-]+\.)*(www\.)?moatads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?admanmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsafeprotected\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mrtnsvr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ohmy\.(bid)$',
#                 '^([\w-]+\.)*(www\.)?yimg\.(com)$',
#                 '^([\w-]+\.)*(www\.)?serving-sys\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?adsmoloco\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsmoloco\.(com)$',
#                 '^([\w-]+\.)*(www\.)?moatads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lkqd\.(net)$',
#                 '^([\w-]+\.)*(www\.)?liadm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?indexww\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ftstatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rtactivate\.(com)$',
#                 '^([\w-]+\.)*(www\.)?avct\.(cloud)$',
#                 '^([\w-]+\.)*(www\.)?adspend\.(space)$',
#                 '^([\w-]+\.)*(www\.)?moatads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mpartner\.(digital)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?ftstatic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?skcrtxr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adpartner\.(pro)$',
#                 '^([\w-]+\.)*(www\.)?minutemedia-prebid\.(com)$',
#                 '^([\w-]+\.)*(www\.)?videohead\.(tech)$',
#                 '^([\w-]+\.)*(www\.)?rtbwave\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pangle-ads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dxkulture\.(com)$',
#                 '^([\w-]+\.)*(www\.)?microad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?weborama-tech\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?microad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?adspector\.(io)$',
#                 '^([\w-]+\.)*(www\.)?appocean\.(media)$',
#                 '^([\w-]+\.)*(www\.)?liadm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?targetads\.(io)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?nowsad\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dom-sad-semena\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?bestssp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidswitch\.(net)$',
#                 '^([\w-]+\.)*(www\.)?microad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?pashadoorsuits\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?video-mech\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?ohmy\.(bid)$',
#                 '^([\w-]+\.)*(www\.)?ck-ie\.(com)$',
#                 '^([\w-]+\.)*(www\.)?fbshare\.(me)$',
#                 '^([\w-]+\.)*(www\.)?1rx\.(io)$',
#                 '^([\w-]+\.)*(www\.)?prmin\.(net)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gplinks\.(in)$',
#                 '^([\w-]+\.)*(www\.)?profit\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?weborama-tech\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?setupad\.(net)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kodiaddonz\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?videohead\.(tech)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?contextweb\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kupit-akkaunt-adsense\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?microad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?microad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?bidswitch\.(net)$',
#                 '^([\w-]+\.)*(www\.)?melvad\.(com)$',
#                 '^([\w-]+\.)*(www\.)?liadm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsmoloco\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adsmoloco\.(com)$',
#                 '^([\w-]+\.)*(www\.)?open-adsyield\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adrta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bidswitch\.(net)$',
#                 '^([\w-]+\.)*(www\.)?admanmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?appsflyersdk\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hsleadflows\.(net)$',
#                 '^([\w-]+\.)*(www\.)?openx\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pashadoorsuits\.(com)$'
#             ]) > 0 THEN 'advertising'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?audrte\.(com)$',
#                 '^([\w-]+\.)*(www\.)?nextmillmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lotus-dsp\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?punchmedia\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?nextmillmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?wal\.(co)$',
#                 '^([\w-]+\.)*(www\.)?detectme\.(net)$',
#                 '^([\w-]+\.)*(www\.)?joisuitesvenezia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rugraphics\.(ru)$'
#             ]) > 0 THEN 'advertising platforms'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?alfasense\.(com)$',
#                 '^([\w-]+\.)*(www\.)?alfasense\.(com)$'
#             ]) > 0 THEN 'advertising/marketing'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?rtb\.(mx)$',
#                 '^([\w-]+\.)*(www\.)?skcrtxr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?skcrtxr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kueezrtb\.(com)$',
#                 '^([\w-]+\.)*(www\.)?serving-sys\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?aarki\.(net)$',
#                 '^([\w-]+\.)*(www\.)?pub\.(network)$',
#                 '^([\w-]+\.)*(www\.)?skcrtxr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hhkld\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ibyteimg\.(com)$',
#                 '^([\w-]+\.)*(www\.)?skcrtxr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?vak-sms\.(com)$',
#                 '^([\w-]+\.)*(www\.)?im-apps\.(net)$',
#                 '^([\w-]+\.)*(www\.)?activemetering\.(com)$',
#                 '^([\w-]+\.)*(www\.)?serviceutility\.(net)$',
#                 '^([\w-]+\.)*(www\.)?ibyteimg\.(com)$',
#                 '^([\w-]+\.)*(www\.)?powered-by-revidy\.(com)$',
#                 '^([\w-]+\.)*(www\.)?udsp\.(io)$',
#                 '^([\w-]+\.)*(www\.)?cameraclickz\.(com)$',
#                 '^([\w-]+\.)*(www\.)?birthbungo\.(click)$',
#                 '^([\w-]+\.)*(www\.)?1rx\.(io)$',
#                 '^([\w-]+\.)*(www\.)?6sc\.(co)$',
#                 '^([\w-]+\.)*(www\.)?aarki\.(net)$',
#                 '^([\w-]+\.)*(www\.)?1conan\.(com)$',
#                 '^([\w-]+\.)*(www\.)?im-apps\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mrmserve\.(com)$',
#                 '^([\w-]+\.)*(www\.)?scroll\.(io)$',
#                 '^([\w-]+\.)*(www\.)?im-apps\.(net)$'
#             ]) > 0 THEN 'advertising/tracking'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?ya\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?ya\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?pusher\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantummetric\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pusher\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantummetric\.(com)$',
#                 '^([\w-]+\.)*(www\.)?statsig\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tumblr\.(com)$',
#                 '^([\w-]+\.)*(www\.)?researchnow\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ravenjs\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quora\.(com)$',
#                 '^([\w-]+\.)*(www\.)?squareup\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantummetric\.(com)$',
#                 '^([\w-]+\.)*(www\.)?foursquare\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ya\.(ru)$'
#             ]) > 0 THEN 'advice'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?afm01\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pbstck\.(com)$'
#             ]) > 0 THEN 'affiliate marketing'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?1rx\.(io)$',
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?eu-1-id5-sync\.(com)$',
#                 '^([\w-]+\.)*(www\.)?opendsp\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?colossusssp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?iesnare\.(com)$',
#                 '^([\w-]+\.)*(www\.)?top100\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?zero\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?solta\.(io)$',
#                 '^([\w-]+\.)*(www\.)?socdm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?processfinger\.(com)$',
#                 '^([\w-]+\.)*(www\.)?programmatica\.(com)$',
#                 '^([\w-]+\.)*(www\.)?prodmp\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?cbhq\.(net)$',
#                 '^([\w-]+\.)*(www\.)?brand-display\.(com)$',
#                 '^([\w-]+\.)*(www\.)?app-analytics-services\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hs-analytics\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mixvisor\.(com)$',
#                 '^([\w-]+\.)*(www\.)?wi-fi\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?im-apps\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rotapost\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?e-volution\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?kueezrtb\.(com)$',
#                 '^([\w-]+\.)*(www\.)?im-apps\.(net)$',
#                 '^([\w-]+\.)*(www\.)?deliveryhero\.(net)$',
#                 '^([\w-]+\.)*(www\.)?bc-sync\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mintegral\.(net)$',
#                 '^([\w-]+\.)*(www\.)?gvt2\.(com)$'
#             ]) > 0 THEN 'analytics/tracking'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?sms-activate\.(io)$',
#                 '^([\w-]+\.)*(www\.)?myinstaapi\.(lat)$',
#                 '^([\w-]+\.)*(www\.)?hafsa\.(de)$',
#                 '^([\w-]+\.)*(www\.)?pfbaza\.(website)$',
#                 '^([\w-]+\.)*(www\.)?scenum\.(io)$',
#                 '^([\w-]+\.)*(www\.)?fantom\.(network)$',
#                 '^([\w-]+\.)*(www\.)?primesurveys\.(com)$',
#                 '^([\w-]+\.)*(www\.)?b2c\.(com)$',
#                 '^([\w-]+\.)*(www\.)?spot\.(im)$',
#                 '^([\w-]+\.)*(www\.)?asocks\.(com)$',
#                 '^([\w-]+\.)*(www\.)?posherva\.(com)$',
#                 '^([\w-]+\.)*(www\.)?apifunctioncall\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gravitec\.(media)$',
#                 '^([\w-]+\.)*(www\.)?bes\.(media)$',
#                 '^([\w-]+\.)*(www\.)?samsunggp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?incogniton\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bitlabs\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?abcsinsights\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rocketapi\.(io)$',
#                 '^([\w-]+\.)*(www\.)?tezhub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zlatnik\.(me)$',
#                 '^([\w-]+\.)*(www\.)?woxo\.(tech)$',
#                 '^([\w-]+\.)*(www\.)?sjapis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?xpluem\.(dev)$'
#             ]) > 0 THEN 'api service'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?a-mo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?a-mo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?a-mo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?a-mo\.(net)$'
#             ]) > 0 THEN 'application and software download'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?ebayadservices\.(com)$'
#             ]) > 0 THEN 'auctions and classified ads'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?imaq\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?chatra\.(io)$'
#             ]) > 0 THEN 'authentication services'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?centrum24\.(pl)$'
#             ]) > 0 THEN 'banking services'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?rabby\.(io)$',
#                 '^([\w-]+\.)*(www\.)?rudub\.(online)$'
#             ]) > 0 THEN 'blockchain services'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?siteblog\.(online)$'
#             ]) > 0 THEN 'blog'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?iqzone\.(com)$',
#                 '^([\w-]+\.)*(www\.)?smilewanted\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?schulmanlaw\.(net)$',
#                 '^([\w-]+\.)*(www\.)?smilewanted\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?germanshepherdproblems\.(com)$',
#                 '^([\w-]+\.)*(www\.)?forter\.(com)$',
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?cookiebot\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?flocktory\.(com)$',
#                 '^([\w-]+\.)*(www\.)?didiglobal\.(com)$',
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?forter\.(com)$',
#                 '^([\w-]+\.)*(www\.)?vidoomy\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?cookiebot\.(com)$',
#                 '^([\w-]+\.)*(www\.)?vidoomy\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?firstimpression\.(io)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?applovin\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?taboola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?somplo\.(com)$',
#                 '^([\w-]+\.)*(www\.)?termly\.(io)$'
#             ]) > 0 THEN 'blogs'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?redditstatic\.(com)$'
#             ]) > 0 THEN 'blogs and forums'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?livejournal\.(net)$',
#                 '^([\w-]+\.)*(www\.)?livejournal\.(net)$'
#             ]) > 0 THEN 'blogs and personal sites'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?widgetbot\.(io)$',
#                 '^([\w-]+\.)*(www\.)?widgetbot\.(io)$',
#                 '^([\w-]+\.)*(www\.)?patent-rabota\.(online)$'
#             ]) > 0 THEN 'bots/automation'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?octobrowser\.(net)$'
#             ]) > 0 THEN 'browser automation'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?aykutcevik\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?aykutcevik\.(com)$',
#                 '^([\w-]+\.)*(www\.)?microsoftonline\.(com)$',
#                 '^([\w-]+\.)*(www\.)?nr-data\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?mathtag\.(com)$',
#                 '^([\w-]+\.)*(www\.)?id5-sync\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sape\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?inner-active\.(mobi)$',
#                 '^([\w-]+\.)*(www\.)?multiloginapp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adspower\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantserve\.(com)$',
#                 '^([\w-]+\.)*(www\.)?unrulymedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rfihub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mts\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mts\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?admixer\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?inner-active\.(mobi)$',
#                 '^([\w-]+\.)*(www\.)?mts\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?hihonor\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantserve\.(com)$',
#                 '^([\w-]+\.)*(www\.)?utraff\.(com)$',
#                 '^([\w-]+\.)*(www\.)?bttrack\.(com)$',
#                 '^([\w-]+\.)*(www\.)?redditmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?cmd328\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rfihub\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sape\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?exelator\.(com)$',
#                 '^([\w-]+\.)*(www\.)?grow\.(me)$',
#                 '^([\w-]+\.)*(www\.)?jivo\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?360yield\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?krxd\.(net)$',
#                 '^([\w-]+\.)*(www\.)?id5-sync\.(com)$',
#                 '^([\w-]+\.)*(www\.)?richaudience\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rtmark\.(net)$',
#                 '^([\w-]+\.)*(www\.)?trustpilot\.(com)$',
#                 '^([\w-]+\.)*(www\.)?quantserve\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adingo\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?uncn\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?krxd\.(net)$',
#                 '^([\w-]+\.)*(www\.)?multiloginapp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?i-sphere\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?unrulymedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?360yield\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?mindbox\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?360yield\.(com)$',
#                 '^([\w-]+\.)*(www\.)?impact-ad\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?mts\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?identrust\.(com)$',
#                 '^([\w-]+\.)*(www\.)?semasio\.(net)$',
#                 '^([\w-]+\.)*(www\.)?samplicio\.(us)$',
#                 '^([\w-]+\.)*(www\.)?vk-portal\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?ib-ibi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inner-active\.(mobi)$',
#                 '^([\w-]+\.)*(www\.)?360yield\.(com)$',
#                 '^([\w-]+\.)*(www\.)?grow\.(me)$',
#                 '^([\w-]+\.)*(www\.)?utraff\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mindbox\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?insightexpressai\.(com)$',
#                 '^([\w-]+\.)*(www\.)?safedk\.(com)$',
#                 '^([\w-]+\.)*(www\.)?imrworldwide\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?redditmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?media6degrees\.(com)$',
#                 '^([\w-]+\.)*(www\.)?scene7\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?adingo\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?fwmrm\.(net)$',
#                 '^([\w-]+\.)*(www\.)?rostelecom\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?adsymptotic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?nr-data\.(net)$',
#                 '^([\w-]+\.)*(www\.)?aralego\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?richaudience\.(com)$',
#                 '^([\w-]+\.)*(www\.)?reestr-pki\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?satu\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?bitrix24\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?grow\.(me)$',
#                 '^([\w-]+\.)*(www\.)?zoon\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?videonow\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?satu\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?adtdp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rtbhouse\.(com)$',
#                 '^([\w-]+\.)*(www\.)?admixer\.(net)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?soloway\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?exelator\.(com)$',
#                 '^([\w-]+\.)*(www\.)?locateplus\.(com)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?fulledu\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?t-mobile\.(pl)$',
#                 '^([\w-]+\.)*(www\.)?tikiwiki\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mts\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?uiscom\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?ssisurveys\.(com)$',
#                 '^([\w-]+\.)*(www\.)?skyviewobservatory\.(com)$',
#                 '^([\w-]+\.)*(www\.)?samplicio\.(us)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?segment\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mistplay\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?fout\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?ipsosinteractive\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gde-luchshe\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?redditmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sypexgeo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?sony\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gopro\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gde-luchshe\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?richaudience\.(com)$',
#                 '^([\w-]+\.)*(www\.)?geojs\.(io)$',
#                 '^([\w-]+\.)*(www\.)?samplicio\.(us)$',
#                 '^([\w-]+\.)*(www\.)?satu\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?mindbox\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?adingo\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?mediatoday\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?tapjoyads\.(com)$',
#                 '^([\w-]+\.)*(www\.)?admixer\.(net)$',
#                 '^([\w-]+\.)*(www\.)?criteo\.(net)$',
#                 '^([\w-]+\.)*(www\.)?bounceexchange\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hybrid\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?crazyegg\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?xfinity\.(com)$',
#                 '^([\w-]+\.)*(www\.)?industrysf\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ryotsuke\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?inner-active\.(mobi)$',
#                 '^([\w-]+\.)*(www\.)?sony\.(com)$',
#                 '^([\w-]+\.)*(www\.)?securedvisit\.(com)$',
#                 '^([\w-]+\.)*(www\.)?rosiyane\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?nr-data\.(net)$',
#                 '^([\w-]+\.)*(www\.)?salt-and-pepper\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?audiobookz\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mathtag\.(com)$',
#                 '^([\w-]+\.)*(www\.)?decipherinc\.(com)$',
#                 '^([\w-]+\.)*(www\.)?fout\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?alot\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adingo\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?amocrm\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?sojern\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adingo\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?becomeananesthesiologist\.(com)$',
#                 '^([\w-]+\.)*(www\.)?iron-samson\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?adform\.(net)$',
#                 '^([\w-]+\.)*(www\.)?fout\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?exelator\.(com)$',
#                 '^([\w-]+\.)*(www\.)?chozamusic\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?terraincognito\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?affec\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?semya-moya\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?retargetly\.(com)$',
#                 '^([\w-]+\.)*(www\.)?gopro\.(com)$',
#                 '^([\w-]+\.)*(www\.)?videonow\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?bttrack\.(com)$',
#                 '^([\w-]+\.)*(www\.)?retargetly\.(com)$',
#                 '^([\w-]+\.)*(www\.)?toluna\.(com)$',
#                 '^([\w-]+\.)*(www\.)?metamask\.(io)$',
#                 '^([\w-]+\.)*(www\.)?mango-office\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?serving-sys\.(com)$',
#                 '^([\w-]+\.)*(www\.)?serving-sys\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adxcel-ec2\.(com)$',
#                 '^([\w-]+\.)*(www\.)?aggle\.(net)$',
#                 '^([\w-]+\.)*(www\.)?redditmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?beeline\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?redditmedia\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pardot\.(com)$',
#                 '^([\w-]+\.)*(www\.)?imrworldwide\.(com)$',
#                 '^([\w-]+\.)*(www\.)?adhaven\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tourvisor\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?dwin1\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?exelator\.(com)$',
#                 '^([\w-]+\.)*(www\.)?springserve\.(com)$',
#                 '^([\w-]+\.)*(www\.)?blentech\.(com)$',
#                 '^([\w-]+\.)*(www\.)?uiscom\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?lpsnmedia\.(net)$',
#                 '^([\w-]+\.)*(www\.)?bitrix24\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?jivo\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mbc-corp\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?samplicio\.(us)$',
#                 '^([\w-]+\.)*(www\.)?assertcom\.(de)$',
#                 '^([\w-]+\.)*(www\.)?callibri\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?askmediagroup\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lpsnmedia\.(net)$',
#                 '^([\w-]+\.)*(www\.)?callibri\.(ru)$'
#             ]) > 0 THEN 'business'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?365lpodds\.(com)$',
#                 '^([\w-]+\.)*(www\.)?halykmarket\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?ult\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?365lpodds\.(com)$',
#                 '^([\w-]+\.)*(www\.)?365lpodds\.(com)$',
#                 '^([\w-]+\.)*(www\.)?365lpodds\.(com)$',
#                 '^([\w-]+\.)*(www\.)?informburo\.(kz)$',
#                 '78.46.211.155',
#                 '^([\w-]+\.)*(www\.)?mommyandlove\.(com)$',
#                 '^([\w-]+\.)*(www\.)?toppress\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?bzserial\.(online)$',
#                 '^([\w-]+\.)*(www\.)?adlook\.(me)$',
#                 '^([\w-]+\.)*(www\.)?whiteboxdigital\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?cnscdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ctnsnet\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ranking\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?b-mode\.(ru)$',
#                 '223.5.5.5',
#                 '^([\w-]+\.)*(www\.)?instreamvideo\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?truffle\.(bid)$',
#                 '^([\w-]+\.)*(www\.)?sfat-ryazan\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?ctnsnet\.(com)$',
#                 '^([\w-]+\.)*(www\.)?co\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?camelia\.(lt)$',
#                 '^([\w-]+\.)*(www\.)?365lpodds\.(com)$',
#                 '^([\w-]+\.)*(www\.)?com\.(au)$',
#                 '^([\w-]+\.)*(www\.)?co\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?com\.(au)$',
#                 '^([\w-]+\.)*(www\.)?censor\.(net)$',
#                 '^([\w-]+\.)*(www\.)?megafonpro\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?censor\.(net)$',
#                 '^([\w-]+\.)*(www\.)?neuruslab\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?zdassets\.(com)$',
#                 '^([\w-]+\.)*(www\.)?pelaezhermanos\.(com)$',
#                 '^([\w-]+\.)*(www\.)?ua-rating\.(com)$',
#                 '^([\w-]+\.)*(www\.)?org\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?sam-master\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zdassets\.(com)$',
#                 '^([\w-]+\.)*(www\.)?instreamvideo\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?com\.(au)$',
#                 '^([\w-]+\.)*(www\.)?uma\.(media)$',
#                 '^([\w-]+\.)*(www\.)?getshop\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?co\.(jp)$',
#                 '^([\w-]+\.)*(www\.)?adlook\.(me)$'
#             ]) > 0 THEN 'business and economy'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?zxpcloud\.(com)$',
#                 '^([\w-]+\.)*(www\.)?privacysandboxservices\.(com)$',
#                 '^([\w-]+\.)*(www\.)?px-cloud\.(net)$',
#                 '^([\w-]+\.)*(www\.)?px-cloud\.(net)$',
#                 '^([\w-]+\.)*(www\.)?px-cloud\.(net)$',
#                 '^([\w-]+\.)*(www\.)?go-mpulse\.(net)$',
#                 '^([\w-]+\.)*(www\.)?px-cloud\.(net)$',
#                 '^([\w-]+\.)*(www\.)?cloudflare-eth\.(com)$',
#                 '^([\w-]+\.)*(www\.)?privacysandboxservices\.(com)$',
#                 '^([\w-]+\.)*(www\.)?px-cloud\.(net)$',
#                 '^([\w-]+\.)*(www\.)?hingeaws\.(net)$',
#                 '^([\w-]+\.)*(www\.)?cloudfunctions\.(net)$',
#                 '^([\w-]+\.)*(www\.)?bybit-aws\.(com)$'
#             ]) > 0 THEN 'cloud services'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?vungle\.(io)$'
#             ]) > 0 THEN 'cloud/hosting'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?googleapis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googleapis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googleapis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googleapis\.(com)$',
# ...
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?btloader\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?btloader\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?optimizely\.(com)$',
#                 '^([\w-]+\.)*(www\.)?acint\.(net)$',
#                 '^([\w-]+\.)*(www\.)?optimizely\.(com)$',
#                 '^([\w-]+\.)*(www\.)?google-analytics\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?moviead55\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?moviead55\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?googleoptimize\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sibautomation\.(com)$',
#                 '^([\w-]+\.)*(www\.)?optimizely\.(com)$',
#                 '^([\w-]+\.)*(www\.)?agkn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?shareaholic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?shareaholic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?videoamp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?optimizely\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?shareaholic\.(com)$',
#                 '^([\w-]+\.)*(www\.)?doubleverify\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?inmobi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$',
#                 '^([\w-]+\.)*(www\.)?zemanta\.(com)$'
#             ]) > 0 THEN 'trackers'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?socdm\.(com)$',
#                 '^([\w-]+\.)*(www\.)?marphezis\.(com)$',
#                 '^([\w-]+\.)*(www\.)?imperium\.(com)$',
#                 '^([\w-]+\.)*(www\.)?setupcmp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?imperium\.(com)$'
#             ]) > 0 THEN 'tracking/advertising'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?hotjar\.(io)$',
#                 '^([\w-]+\.)*(www\.)?shortpixel\.(ai)$',
#                 '^([\w-]+\.)*(www\.)?konnektu\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?onetarget\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?pixelscan\.(net)$',
#                 '^([\w-]+\.)*(www\.)?s3xified\.(com)$',
#                 '^([\w-]+\.)*(www\.)?metatrckpixel\.(com)$'
#             ]) > 0 THEN 'tracking/analytics'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?stickyadstv\.(com)$',
#                 '^([\w-]+\.)*(www\.)?demdex\.(net)$',
#                 '^([\w-]+\.)*(www\.)?yvision\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?studiocity-macau\.(com)$',
#                 '103.252.142.21',
#                 '103.252.142.18',
#                 '103.252.142.19',
#                 '^([\w-]+\.)*(www\.)?yvision\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?demdex\.(net)$',
#                 '^([\w-]+\.)*(www\.)?demdex\.(net)$',
#                 '^([\w-]+\.)*(www\.)?sentry-cdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?kaucanainn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?japandomesticmotor\.(com)$',
#                 '^([\w-]+\.)*(www\.)?expedia\.(de)$',
#                 '^([\w-]+\.)*(www\.)?2gis\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?airbnb\.(com)$',
#                 '^([\w-]+\.)*(www\.)?tripadvisor\.(com)$',
#                 '^([\w-]+\.)*(www\.)?cityline\.(com)$',
#                 '^([\w-]+\.)*(www\.)?sentry-cdn\.(com)$'
#             ]) > 0 THEN 'travel'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?anextour\.(lt)$',
#                 '^([\w-]+\.)*(www\.)?anextour\.(lv)$',
#                 '^([\w-]+\.)*(www\.)?anextour\.(ee)$'
#             ]) > 0 THEN 'travel/booking'
#             WHEN multiMatchAny(req_host, [
#                 '91.206.127.40',
#                 '103.253.43.142',
#                 '95.163.138.146',
#                 '62.113.116.50',
#                 '194.187.245.92',
#                 '193.232.108.94',
#                 '^([\w-]+\.)*(www\.)?fxdx\.(in)$',
#                 '185.169.155.69',
#                 '95.216.158.241',
#                 '45.152.188.222',
#                 '199.48.177.23',
#                 '64.226.90.219',
#                 '173.244.48.9',
#                 '108.165.142.16',
#                 '173.244.48.11',
#                 '139.180.189.170',
#                 '157.245.38.100',
#                 '164.92.143.246',
#                 '207.148.15.194',
#                 '45.32.148.164',
#                 '207.148.125.99',
#                 '45.77.214.241',
#                 '164.92.176.77',
#                 '144.126.230.202',
#                 '45.152.188.17',
#                 '149.19.224.12',
#                 '66.42.69.9',
#                 '65.20.112.8',
#                 '178.128.169.149',
#                 '164.92.143.154',
#                 '95.179.193.36',
#                 '108.165.142.32',
#                 '139.180.143.119',
#                 '159.89.41.97',
#                 '159.223.41.14',
#                 '149.28.126.149',
#                 '143.198.201.39',
#                 '134.122.65.23',
#                 '176.118.167.29',
#                 '144.202.53.98',
#                 '^([\w-]+\.)*(www\.)?tmn\.(one)$',
#                 '88.212.240.204',
#                 '85.198.79.1',
#                 '178.248.234.78',
#                 '85.198.79.24',
#                 '142.250.188.228',
#                 '142.250.72.238',
#                 '142.250.68.106',
#                 '^([\w-]+\.)*(www\.)?alfasense\.(net)$',
#                 '142.250.68.99',
#                 '^([\w-]+\.)*(www\.)?lordserial\.(media)$',
#                 '142.251.40.33',
#                 '91.238.111.248',
#                 '129.134.140.131',
#                 '93.190.126.19',
#                 '107.178.251.134',
#                 '198.167.222.108',
#                 '151.236.121.248',
#                 '182.161.73.142',
#                 '66.29.132.136',
#                 '185.71.67.88',
#                 '151.236.124.252',
#                 '151.236.89.224',
#                 '163.70.137.60',
#                 '213.180.204.52',
#                 '87.250.250.36',
#                 '142.250.72.228',
#                 '142.251.40.36',
#                 '163.70.132.60',
#                 '^([\w-]+\.)*(www\.)?shinservice-shop\.(ru)$',
#                 '185.165.123.77',
#                 '142.250.150.84',
#                 '142.250.72.164',
#                 '154.92.27.6',
#                 '154.59.122.79',
#                 '91.240.169.232',
#                 '142.250.68.4',
#                 '87.250.251.15',
#                 '142.250.68.68',
#                 '5.101.40.37',
#                 '91.231.236.240',
#                 '182.161.73.152'
#             ]) > 0 THEN 'unknown'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?kolesa\.(kz)$',
#                 '^([\w-]+\.)*(www\.)?classistatic\.(de)$',
#                 '^([\w-]+\.)*(www\.)?mobile\.(de)$',
#                 '^([\w-]+\.)*(www\.)?botfaqtor\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?auto\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?toyota\.(eu)$',
#                 '^([\w-]+\.)*(www\.)?lexus\.(hu)$',
#                 '^([\w-]+\.)*(www\.)?apemotors\.(lv)$',
#                 '^([\w-]+\.)*(www\.)?mobile\.(de)$',
#                 '^([\w-]+\.)*(www\.)?forum-macan\.(ru)$'
#             ]) > 0 THEN 'vehicles'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?showjet\.(tv)$'
#             ]) > 0 THEN 'video hosting'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?lordfilm\.(vision)$',
#                 '^([\w-]+\.)*(www\.)?lordfilm\.(moda)$',
#                 '^([\w-]+\.)*(www\.)?watchfeed\.(tv)$',
#                 '^([\w-]+\.)*(www\.)?7lordfilm-0\.(xyz)$',
#                 '^([\w-]+\.)*(www\.)?lordfilm0\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lordfilm-online\.(cc)$',
#                 '^([\w-]+\.)*(www\.)?my-lordfilms\.(com)$',
#                 '^([\w-]+\.)*(www\.)?lordserial\.(run)$',
#                 '^([\w-]+\.)*(www\.)?lordfilm7\.(link)$',
#                 '^([\w-]+\.)*(www\.)?garfield-lordfilm\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?lordfilms\.(gg)$',
#                 '^([\w-]+\.)*(www\.)?spider-man-lordfilm\.(net)$',
#                 '^([\w-]+\.)*(www\.)?lordfilm\.(art)$'
#             ]) > 0 THEN 'video streaming'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?buzzoola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?buzzoola\.(com)$',
#                 '^([\w-]+\.)*(www\.)?primis\.(tech)$',
#                 '^([\w-]+\.)*(www\.)?vimeocdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?vimeocdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?vimeocdn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?redgifs\.(com)$'
#             ]) > 0 THEN 'videos'
#             WHEN multiMatchAny(req_host, [
#                 '172.217.18.10',
#                 '172.217.16.195',
#                 '172.217.16.206',
#                 '172.217.12.99',
#                 '172.217.12.106',
#                 '172.217.18.14'
#             ]) > 0 THEN 'visual search'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?anty-proxy-checker\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dolphin-anty-mirror\.(net)$',
#                 '^([\w-]+\.)*(www\.)?dolphin-anty-mirror\.(com)$',
#                 '^([\w-]+\.)*(www\.)?4g-proxy\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?topsbor\.(com)$',
#                 '^([\w-]+\.)*(www\.)?myclientip\.(com)$',
#                 '^([\w-]+\.)*(www\.)?youtube-booster\.(space)$',
#                 '^([\w-]+\.)*(www\.)?hubstudio\.(vip)$',
#                 '^([\w-]+\.)*(www\.)?98yl795\.(vip)$',
#                 '^([\w-]+\.)*(www\.)?nip\.(io)$',
#                 '^([\w-]+\.)*(www\.)?canhazip\.(com)$',
#                 '^([\w-]+\.)*(www\.)?browsiprod\.(com)$',
#                 '^([\w-]+\.)*(www\.)?script\.(ac)$',
#                 '^([\w-]+\.)*(www\.)?octoproxycheck\.(com)$',
#                 '^([\w-]+\.)*(www\.)?marquiz\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?fb\.(rip)$',
#                 '^([\w-]+\.)*(www\.)?script\.(ac)$',
#                 '^([\w-]+\.)*(www\.)?ziparchive\.(xyz)$',
#                 '^([\w-]+\.)*(www\.)?ipvsn\.(com)$',
#                 '^([\w-]+\.)*(www\.)?dotomi\.(com)$',
#                 '^([\w-]+\.)*(www\.)?browsiprod\.(com)$',
#                 '^([\w-]+\.)*(www\.)?browsiprod\.(com)$',
#                 '^([\w-]+\.)*(www\.)?hs-scripts\.(com)$',
#                 '^([\w-]+\.)*(www\.)?wynd\.(network)$'
#             ]) > 0 THEN 'vpn/proxy'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?digitaltarget\.(ru)$',
#                 '87.250.250.119',
#                 '87.250.251.119',
#                 '93.158.134.119',
#                 '^([\w-]+\.)*(www\.)?sc-static\.(net)$',
#                 '162.247.243.29',
#                 '^([\w-]+\.)*(www\.)?digitaltarget\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mozgcp\.(net)$',
#                 '^([\w-]+\.)*(www\.)?soflopxl\.(com)$',
#                 '^([\w-]+\.)*(www\.)?skwstat\.(ru)$'
#             ]) > 0 THEN 'web analytics'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$',
#                 '^([\w-]+\.)*(www\.)?com\.(ua)$'
#             ]) > 0 THEN 'web hosting'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?kimberlite\.(io)$',
#                 '^([\w-]+\.)*(www\.)?sda\.(fyi)$',
#                 '^([\w-]+\.)*(www\.)?qtarget\.(tech)$',
#                 '^([\w-]+\.)*(www\.)?wbbasket\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mobilebanner\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?wbbasket\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?wbbasket\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?aliapp\.(org)$',
#                 '^([\w-]+\.)*(www\.)?usemessages\.(com)$'
#             ]) > 0 THEN 'web infrastructure'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?aura-dsp\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?textnow\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?textnow\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?gmail\.(com)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$',
#                 '^([\w-]+\.)*(www\.)?mail\.(ru)$'
#             ]) > 0 THEN 'webmail'
#             WHEN multiMatchAny(req_host, [
#                 '^([\w-]+\.)*(www\.)?wixapps\.(net)$'
#             ]) > 0 THEN 'website tools'
#         ELSE 'other' END req_category2
#         from zprx.zproxy_reqs_v1__merge zrvm
#         where 1=1
#             and toYYYYMM(ts_millis) = toYYYYMM(toDate('2021-09-18'))
#             and ts_millis > toDateTime('2021-09-18')
#             and ts_millis <= addHours(toDateTime('2021-09-18'), 24)
# )
# select
#     req_category2,
#     count(*) as cnt
# from a
# group by
#     req_category2
# order by
#     cnt desc

# %% [markdown]
# 1. Загрузка библиотек: Библиотеки, необходимые для работы с данными и операциями с паролями, операционной системой, JSON и строками, были успешно импортированы. Это обеспечило необходимую функциональность для дальнейшей обработки данных.
#
# 2. Выгрузка данных: Данные из CSV файла combined_hosts_with_fixed_regex_v4.csv были загружены в DataFrame. Использование метода value_counts() позволило подсчитать уникальные значения в столбце 'cat_popular', что помогло выявить распределение категорий.
#
# 3. Агрегация данных: Данные были сгруппированы по столбцу 'cat_popular', и для каждой категории был собран список значений из столбца 'url_regex_mod'. Это позволило создать новый DataFrame df_reg_unite, в котором каждая категория была представлена списком связанных значений.
#
# 4. Формирование SQL запроса: Строка SQL-запроса была сформирована, начиная с подзапроса, в котором создавались условия для классификации req_host по категориям. Для каждой категории из df_reg_unite были добавлены соответствующие условия WHEN, проверяющие соответствие доменов в req_host.
#
# 5. Заполнение и завершение строки запроса: Были добавлены строки с условиями WHEN, в которых домены, полученные из списка в df_reg_unite, добавлялись с использованием метода join(). В результате строка запроса была дополнена необходимыми условиями и
